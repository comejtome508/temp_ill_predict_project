# %%
# 일단 폭염일 때 가장 많은 질병 10개를 골라야함.

import pandas as pd
join = pd.read_csv("22_10_14년도_30도이상_건강검진과inner.csv")
join.head()
# Out:
# C:\Users\haeunlove\AppData\Local\Temp\ipykernel_11868\3077453725.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   join = pd.read_csv("22_10_14년도_30도이상_건강검진과inner.csv")
#    Unnamed: 0  기준년도_x  가입자일련번호  진료내역일련번호  성별코드  연령대코드  시도코드_x    요양개시일자  서식코드  \
# 0           0    2010   738356      7074     1     11      11  20100904     3
# 1           1    2010   738356   4206105     1     11      11  20100723     3
# 2           2    2010   738356   5371901     1     11      11  20100706     3
# 3           3    2012   738356   5121724     1      6      31  20120808     3
# 4           4    2014   738356   4315298     2     15      47  20140529     8
#
#    진료과목코드  ...  요단백 혈청크레아티닌  혈청지오티(AST)  혈청지피티(ALT)  감마지티피  흡연상태  음주여부  \
# 0      15  ...  1.0     0.9        38.0        93.0   33.0   3.0   0.0
# 1      13  ...  1.0     0.9        38.0        93.0   33.0   3.0   0.0
# ...

# %%
join.shape
# Out:
# (1287472, 49)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import seaborn as sns

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x")
mpl.style.use("default")
mpl.rcParams.update({"figure.constrained_layout.use": True})

sns.set_context("paper") 
sns.set_palette("Set2") 
sns.set_style("whitegrid") 

plt.rc("font", family = "Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# %%
up_20_sam_counts = join.value_counts("주상병코드")

plt.bar(up_20_sam_counts.index[:20], up_20_sam_counts.values[:20])
plt.title("기온 30도 이상 발병 질병 중 빈도수 상위 20")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sum(y_bar[:20])
# Out:
# 22517

# %%
join.to_csv("2022년도_진료_온도_500개이하_제거.csv", encoding="utf-8-sig")

# %%
y_bar[10]
# Out:
# 538

# %%
up_30.to_csv("2022년도_진료_온도_500개이하_제거_30up.csv", encoding="utf-8-sig")
